# %%
import exploration as exp

# %%
n_chunks = 10

min_ = 0
max_ = 10000
for i in range(n_chunks):
   exp.usr_exploration(min_, max_, step=1000, output_data_folder=f'chunk_{i}',)
   min_ = max_
   max_+= 10000
# Out:
# Process 0 did not converge in time → killed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 max_ = 10000
#       5 for i in range(n_chunks):
# ----> 6    exp.usr_exploration(min_, max_, step=1000, output_data_folder=f'chunk_{i}',)
#       7    min_ = max_
#       8    max_+= 10000
#
# File ~/projects/labolsa/explortation/exploration.py:79, in usr_exploration(min_, max_, step, output_data_folder, vars, json_name, time_out)
#      71    with open('data/' + output_data_folder+filename, 'w') as file:
#      72       file.write(log['output'])
#      75 clean_data = {
#      76    str(k): {
#      77       "x_used": int(v["x_used"]),
#      78       "output": str(v["output"]),
# ---> 79       "execute_time": float(v["execute_time"])
#      80    }
#      81    for k, v in maping_data.items()
#      82 }
# ...

# %% [markdown]
# # Intervalo 1 [500 - 0]
